# %% [markdown]
# I. Project description: Business intelligence report for Cyclistic to study customer boarding activities across different locations
#
# Aim of project: Identifying customer demands at different station locations.
#
# Client: Cyclistic
#
# Links:
#
# - Stakeholder requirements document: [Cyclistic SRD Link](https://docs.google.com/document/d/1HhNJ_gUZu2MxOHwFTp6dTgB6vza-0ZmZmTuT2uTb3s0/edit?usp=drive_link&resourcekey=0-9lPYg3ptokmEKqF49sjsOA)
#
# - Project requirements document: [Cyclistic PRD Link](https://docs.google.com/document/d/1PHZv2RC3MYcjm3fs9oLMfXE_qS0Fg16iSJzNuOAudAU/edit?usp=drive_link)
#
# - Strategy document: [Cyclistic SD Link](https://docs.google.com/document/d/1_FyTGXI_B6dL0jfymzEsn4FysoklCz_6aACmpnX--Oc/edit?usp=drive_link&resourcekey=0-04ofg_eJIUN2T4ewmweHTQ)
#
#
# II. Project description: Business intelligence report for MarkIT to discover transaction patterns within the platform
#
# Aim of project: To understand how sellers and buyers interact on the MarkIT sales platform.
#
# Client: MarkIT
#
# Links:
#
# - Stakeholder requirements document: [MarkIT SRD Link](https://docs.google.com/document/d/1DQjwPTdeOvvcsVEToDbODdJHi6QNxopbhQJprI0NVBs/edit?usp=drive_link&resourcekey=0-JkpJCNtWRtYwvA72ED5ccw)
#
# - Project requirements document: [MarkIT PRD Link](https://docs.google.com/document/d/1JjtXC_brBycNYMU3C52wU6Z-5jYsi-FMdT8b-nbXMlM/edit?usp=drive_link)
#
# - Strategy document: [MarkIT SD Link](https://docs.google.com/document/d/1bvQTR50sDxqBnOuz7nWwCcAq_y3L9rjwAHmHknImUYA/edit?resourcekey=0-92LZvhbSGFJucSDbmHipFw#heading=h.bw4sh12dc86m)
#
#
# III. Project description: Business intelligence report for Google Fiber to explore trends in repeat callers
#
# Aim of project: To understand how often customers phone customer support again after their first inquiry.
#
# Client: Google Fiber
#
# Links:
#
# - Stakeholder requirements document: [Google Fiber SRD Link](https://docs.google.com/document/d/1iXXOW0gxS4HDbtFPQNdPPs2W885uC-Gs2Qsq-b9Yovc/edit?usp=drive_link)
#
# - Project requirements document: [Google Fiber PRD Link](https://docs.google.com/document/d/1fa8F3aigYxM8ub3aCKzj0l-dfK1fNMw_6FkwqP4wkQM/edit?usp=drive_link)
#
# - Strategy document: [Google Fiber SD Link](https://docs.google.com/document/d/1xscIhY0596shof6bAKlOKHcc4vi4Qrzh0XVc7CXtW6g/edit?usp=drive_web&ouid=107030164800771719853)
